# %% [markdown]
# # Exploratory Data Analysis on Dataset - Terrorism

# %% [markdown]
# The aim of this Project is to find out the hot zone of terrorism from a data of Terrorism Occured Every Year. The Data is given in .csv file.
#
# Dataset: https://bit.ly/2TK5Xn5
#
# Presenting an Analysis of the data by
# 1. Year Wise Attacks
# 2. Year Wise Regional Attacks
# 3. Year Wise Attack Type Attacks
# 4. Year Wise Target Type Attacks
# 5. Year Wise Weapon Type Attacks
# 6. Year Wise Country Attacks
# 7. Motive of The Attacks

# %%
#ALL THE LIBRARIES REQUIRED
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline

# %%
#DATA COLLECTION
data=pd.read_csv('globalterrorismdb_0718dist.csv',encoding='latin1')
df=pd.DataFrame(data)
# Out:
# C:\Users\RIYA BONGIRWAR\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning:
#
# Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types.Specify dtype option on import or set low_memory=False.

# %%
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
#A SIMPLE UNDERSTANDING TOWARDS DATASET
df.shape
# Out:
# (181691, 135)

# %%
df.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
df['iyear'].unique
# Out:
# <bound method Series.unique of 0         1970
# 1         1970
# 2         1970
# 3         1970
# 4         1970
#           ...
# 181686    2017
# 181687    2017
# 181688    2017
# 181689    2017
# 181690    2017
# Name: iyear, Length: 181691, dtype: int64>

# %%
for i in df.columns:
    print(i,end=" , ")
# Out:
# eventid , iyear , imonth , iday , approxdate , extended , resolution , country , country_txt , region , region_txt , provstate , city , latitude , longitude , specificity , vicinity , location , summary , crit1 , crit2 , crit3 , doubtterr , alternative , alternative_txt , multiple , success , suicide , attacktype1 , attacktype1_txt , attacktype2 , attacktype2_txt , attacktype3 , attacktype3_txt , targtype1 , targtype1_txt , targsubtype1 , targsubtype1_txt , corp1 , target1 , natlty1 , natlty1_txt , targtype2 , targtype2_txt , targsubtype2 , targsubtype2_txt , corp2 , target2 , natlty2 , natlty2_txt , targtype3 , targtype3_txt , targsubtype3 , targsubtype3_txt , corp3 , target3 , natlty3 , natlty3_txt , gname , gsubname , gname2 , gsubname2 , gname3 , gsubname3 , motive , guncertain1 , guncertain2 , guncertain3 , individual , nperps , nperpcap , claimed , claimmode , claimmode_txt , claim2 , claimmode2 , claimmode2_txt , claim3 , claimmode3 , claimmode3_txt , compclaim , weaptype1 , w
# ...

# %%
#ALL THE REQUIRED COLUMNS FOR ANALYSIS
df=df[['iyear' , 'imonth' , 'iday' ,'country_txt','region_txt', 'provstate' , 'city' ,'latitude','longitude','location','summary','attacktype1_txt','targtype1_txt','gname','motive','weaptype1_txt','nkill','nwound','addnotes']]
df.head()
# Out:
#    iyear  imonth  iday         country_txt                   region_txt  \
# 0   1970       7     2  Dominican Republic  Central America & Caribbean
# 1   1970       0     0              Mexico                North America
# 2   1970       1     0         Philippines               Southeast Asia
# 3   1970       1     0              Greece               Western Europe
# 4   1970       1     0               Japan                    East Asia
#
#   provstate           city   latitude   longitude location summary  \
# 0       NaN  Santo Domingo  18.456792  -69.951164      NaN     NaN
# 1   Federal    Mexico city  19.371887  -99.086624      NaN     NaN
# 2    Tarlac        Unknown  15.478598  120.599741      NaN     NaN
# 3    Attica         Athens  37.997490   23.762728      NaN     NaN
# 4   Fukouka        Fukouka  33.580412  130.396361      NaN     NaN
#
#                   attacktype1_txt                targtype1_txt  \
# ...

# %%
df.value_counts('provstate')
# Out:
# provstate
# Baghdad                                            7645
# Northern Ireland                                   4498
# Unknown                                            4290
# Balochistan                                        3710
# Saladin                                            3411
#                                                    ...
# Lipetsk                                               1
# Lipkovo (Municipality)                                1
# Lipkovo (Region)                                      1
# Ljubljana                                             1
# (Region) of Republican Subordination (Province)       1
# Length: 2855, dtype: int64

# %%
df.value_counts('city')
# Out:
# city
# Unknown                       9775
# Baghdad                       7589
# Karachi                       2652
# Lima                          2359
# Mosul                         2265
#                               ...
# Mazraat al-Qabeer                1
# Mazraha                          1
# Mazro                            1
# Mazu                             1
# 62 miles South of Dushanbe       1
# Length: 36674, dtype: int64

# %%
df.value_counts('summary')
# Out:
# summary
# 09/00/2016: Sometime between September 18, 2016 and September 24, 2016, assailants detonated an explosive device at a civilian house in Dawr, Saladin, Iraq. There were no reported casualties resulting from the blast. No group claimed responsibility for the incident; however, sources attributed the attack to the Islamic State of Iraq and the Levant (ISIL).    100
# 12/01/2016: Assailants detonated explosive devices that destroyed an electricity transmission tower in Albu Bali, Al Anbar, Iraq. This was one of 80 similar attacks targeting towers that resulted in the death of two military engineering team members. No group claimed responsibility for the incidents.                                                             80
# ...

# %%
df.corr()
# Out:
#               iyear    imonth      iday  latitude  longitude     nkill  \
# iyear      1.000000  0.000139  0.018254  0.166933   0.003917  0.015341
# imonth     0.000139  1.000000  0.005497 -0.015978  -0.003880  0.003463
# iday       0.018254  0.005497  1.000000  0.003423  -0.002285 -0.003693
# latitude   0.166933 -0.015978  0.003423  1.000000   0.001463 -0.018124
# longitude  0.003917 -0.003880 -0.002285  0.001463   1.000000 -0.000562
# nkill      0.015341  0.003463 -0.003693 -0.018124  -0.000562  1.000000
# nwound     0.015273  0.002938 -0.001268  0.015988   0.000223  0.534375
#
#              nwound
# iyear      0.015273
# imonth     0.002938
# iday      -0.001268
# latitude   0.015988
# longitude  0.000223
# nkill      0.534375
# nwound     1.000000

# %%
#To Check NuLL Entries
df.isnull().sum()
# Out:
# iyear                   0
# imonth                  0
# iday                    0
# country_txt             0
# region_txt              0
# provstate             421
# city                  434
# latitude             4556
# longitude            4557
# location           126196
# summary             66129
# attacktype1_txt         0
# targtype1_txt           0
# gname                   0
# motive             131130
# weaptype1_txt           0
# nkill               10313
# nwound              16311
# addnotes           153402
# dtype: int64

# %%
#HANDLING MISSING VALUES
df['nkill']=df['nkill'].fillna(0)
df['nwound']=df['nwound'].fillna(0)
df['Affected']=df['nkill']+df['nwound']

# %% [markdown]
# # 1)Year wise Attacks

# %%
a1= df['iyear'].value_counts(dropna=False)
a2= a1.sort_index()
a3= a2.to_frame().reset_index().rename(columns={'index':'iyear','iyear':'Attacks'})
attacks= a3.set_index('iyear')
print(attacks)
# Out:
#        Attacks
# iyear
# 1970       651
# 1971       471
# 1972       568
# 1973       473
# 1974       581
# 1975       740
# 1976       923
# 1977      1319
# 1978      1526
# 1979      2662
# 1980      2662
# 1981      2586
# 1982      2544
# 1983      2870
# 1984      3495
# 1985      2915
# 1986      2860
# 1987      3183
# 1988      3721
# 1989      4324
# 1990      3887
# 1991      4683
# 1992      5071
# 1994      3456
# 1995      3081
# 1996      3058
# 1997      3197
# 1998       934
# 1999      1395
# 2000      1814
# 2001      1906
# 2002      1333
# 2003      1278
# 2004      1166
# 2005      2017
# 2006      2758
# 2007      3242
# 2008      4805
# 2009      4721
# 2010      4826
# 2011      5076
# 2012      8522
# 2013     12036
# 2014     16903
# 2015     14965
# 2016     13587
# 2017     10900

# %%
sns.jointplot(x='iyear',y='Attacks',data=attacks,kind='scatter')

# %%
attacks.plot(kind='bar',figsize=(13,6),fontsize=10)
plt.title('Attacks Every Year',fontsize=13)
plt.xlabel('Years',fontsize=13)
plt.ylabel('Attacks',fontsize=13)
plt.show()

# %% [markdown]
# *The most of the attacks happened to be in 2014(Which is 16903).
#
# *The least number of attacks happened to be in 1971(Which is 471).

# %%
#YEAR WISE AFFECTED
YC=df[['iyear','Affected']].groupby('iyear').sum()
YC
# Out:
#        Affected
# iyear
# 1970      386.0
# 1971      255.0
# 1972      975.0
# 1973      865.0
# 1974     1404.0
# 1975     1234.0
# 1976     1430.0
# 1977      974.0
# 1978     3059.0
# 1979     4606.0
# 1980     8045.0
# 1981     8188.0
# 1982     8478.0
# 1983    13491.0
# 1984    15741.0
# 1985    12224.0
# 1986    10790.0
# 1987    12257.0
# 1988    14168.0
# 1989    13691.0
# 1990    13276.0
# 1991    16020.0
# 1992    19657.0
# 1994    15259.0
# 1995    20395.0
# 1996    17761.0
# 1997    19996.0
# 1998    12871.0
# 1999     8734.0
# 2000    10272.0
# 2001    30503.0
# 2002    11967.0
# 2003    10701.0
# 2004    17765.0
# 2005    19115.0
# 2006    24930.0
# 2007    35348.0
# 2008    28155.0
# 2009    28411.0
# 2010    23774.0
# 2011    22905.0
# 2012    40942.0
# 2013    59961.0
# 2014    85618.0
# 2015    82896.0
# 2016    74872.0
# 2017    51372.0

# %%
YC.plot(kind='bar',figsize=(12,6))
plt.title('People Got both Killed and Wounded (Affected) every Year')
plt.xlabel('Year',fontsize=12)
plt.ylabel('Affected',fontsize=12)
plt.show()

# %% [markdown]
# *Most of the people got affected in 2014(Which is 85618)
#
# *Least of the people got affected in 1971(which is 255)

# %%
#YEAR WISE GOT KILLED
YK=df[['iyear','nkill']].groupby('iyear').sum()
YK
# Out:
#          nkill
# iyear
# 1970     174.0
# 1971     173.0
# 1972     566.0
# 1973     370.0
# 1974     539.0
# 1975     617.0
# 1976     674.0
# 1977     456.0
# 1978    1459.0
# 1979    2100.0
# 1980    4400.0
# 1981    4851.0
# 1982    5136.0
# 1983    9444.0
# 1984   10450.0
# 1985    7094.0
# 1986    4976.0
# 1987    6482.0
# 1988    7208.0
# 1989    8152.0
# 1990    7148.0
# 1991    8429.0
# 1992    9742.0
# 1994    7690.0
# 1995    6103.0
# 1996    6966.0
# 1997   10924.0
# 1998    4688.0
# 1999    3393.0
# 2000    4403.0
# 2001    7729.0
# 2002    4805.0
# 2003    3317.0
# 2004    5743.0
# 2005    6331.0
# 2006    9380.0
# 2007   12824.0
# 2008    9157.0
# 2009    9273.0
# 2010    7827.0
# 2011    8246.0
# 2012   15497.0
# 2013   22273.0
# 2014   44490.0
# 2015   38853.0
# 2016   34871.0
# 2017   26445.0

# %%
YK.plot(kind='bar',figsize=(12,6))
plt.title('People Got Killed every Year')
plt.xlabel('Year',fontsize=12)
plt.ylabel('Killed',fontsize=12)
plt.show()

# %% [markdown]
# *Most of the people got Killed in 2014(Which is 44490)
#
# *Least of the people got Killed in 1971(which is 173))

# %%
#YEAR WISE GOT WOUNDED
YW=df[['iyear','nwound']].groupby('iyear').sum()
YW
# Out:
#         nwound
# iyear
# 1970     212.0
# 1971      82.0
# 1972     409.0
# 1973     495.0
# 1974     865.0
# 1975     617.0
# 1976     756.0
# 1977     518.0
# 1978    1600.0
# 1979    2506.0
# 1980    3645.0
# 1981    3337.0
# 1982    3342.0
# 1983    4047.0
# 1984    5291.0
# 1985    5130.0
# 1986    5814.0
# 1987    5775.0
# 1988    6960.0
# 1989    5539.0
# 1990    6128.0
# 1991    7591.0
# 1992    9915.0
# 1994    7569.0
# 1995   14292.0
# 1996   10795.0
# 1997    9072.0
# 1998    8183.0
# 1999    5341.0
# 2000    5869.0
# 2001   22774.0
# 2002    7162.0
# 2003    7384.0
# 2004   12022.0
# 2005   12784.0
# 2006   15550.0
# 2007   22524.0
# 2008   18998.0
# 2009   19138.0
# 2010   15947.0
# 2011   14659.0
# 2012   25445.0
# 2013   37688.0
# 2014   41128.0
# 2015   44043.0
# 2016   40001.0
# 2017   24927.0

# %%
YW.plot(kind='bar',figsize=(12,6))
plt.title('People Got Wound every Year')
plt.xlabel('Year',fontsize=12)
plt.ylabel('Wounded',fontsize=12)
plt.show()

# %% [markdown]
# *Most of the people got wounded in 2015(Which is 44043)
#
# *Least of the people got wounded in 1971(which is 82)

# %% [markdown]
# # 2) Year Wise Regional Attacks

# %%
YR=pd.crosstab(df.iyear,df.region_txt)
YR.head()
# Out:
# region_txt  Australasia & Oceania  Central America & Caribbean  Central Asia  \
# iyear
# 1970                            1                            7             0
# 1971                            1                            5             0
# 1972                            8                            3             0
# 1973                            1                            6             0
# 1974                            1                           11             0
#
# region_txt  East Asia  Eastern Europe  Middle East & North Africa  \
# iyear
# 1970                2              12                          28
# 1971                1               5                          55
# 1972                0               1                          53
# 1973                2               1                          19
# 1974                4               2                          42
#
# region_txt  North America  South America  South Asia  Southeast Asia  \
# iyear
# ...

# %%
YR.plot(kind='area',figsize=(12,6),)
plt.title('Attacks in Every Region in between 1970-2017')
plt.xlabel('Year')
plt.ylabel('Attacks')
plt.show()

# %%
YRT=YR.transpose()
YRT['Total']=YRT.sum(axis=1)
activities=YRT['Total'].sort_values(ascending=False)
activities
# Out:
# region_txt
# Middle East & North Africa     50474
# South Asia                     44974
# South America                  18978
# Sub-Saharan Africa             17550
# Western Europe                 16639
# Southeast Asia                 12485
# Central America & Caribbean    10344
# Eastern Europe                  5144
# North America                   3456
# East Asia                        802
# Central Asia                     563
# Australasia & Oceania            282
# Name: Total, dtype: int64

# %%
activities.dtypes
# Out:
# dtype('int64')

# %%
activities.plot(kind='bar',figsize=(12,6))
plt.title('number of attacks in each region in between 1970-2017')
plt.xlabel('Region')
plt.ylabel('Attacks')
plt.show()

# %% [markdown]
# *Most of the Attacks where happened in Middle East & North Africa(i.e 50474)
#
# *Least of the Attacks where happened in Australasia & Oceania(i.e 282)

# %%
#REGION WISE AFFECTED
RC=df[['region_txt','Affected']].groupby('region_txt').sum()
RC
# Out:
#                              Affected
# region_txt
# Australasia & Oceania           410.0
# Central America & Caribbean   37699.0
# Central Asia                   3009.0
# East Asia                     10365.0
# Eastern Europe                19460.0
# Middle East & North Africa   351950.0
# North America                 26447.0
# South America                 45553.0
# South Asia                   242679.0
# Southeast Asia                41896.0
# Sub-Saharan Africa           131243.0
# Western Europe                25026.0

# %%
RC.plot(kind='bar',figsize=(12,6))
plt.title('Affected in each region',fontsize=10)
plt.xlabel('Region',fontsize=10)
plt.ylabel('Affected',fontsize=10)
plt.show()

# %% [markdown]
# *Most of the people got Affected in Middle East & North Africa(i.e 351950)
#
# *Least of the people got Affected in Australasia & Oceania(i.e 410)

# %%
#REGION WISE KILLED
RK=df[['region_txt','nkill']].groupby('region_txt').sum()
RK
# Out:
#                                 nkill
# region_txt
# Australasia & Oceania           150.0
# Central America & Caribbean   28708.0
# Central Asia                   1000.0
# East Asia                      1152.0
# Eastern Europe                 7415.0
# Middle East & North Africa   137642.0
# North America                  4916.0
# South America                 28849.0
# South Asia                   101319.0
# Southeast Asia                15637.0
# Sub-Saharan Africa            78386.0
# Western Europe                 6694.0

# %%
RK.plot(kind='bar',figsize=(12,6))
plt.title('No. of People Killed in each region',fontsize=10)
plt.xlabel('Region',fontsize=10)
plt.ylabel('Killed',fontsize=10)
plt.show()

# %% [markdown]
# *Most of the people got Killed in Middle East & North Africa(i.e 137642)
#
# *Least of the people got Killed in Australasia & Oceania(i.e 150)

# %%
#REGION WISE WOUND
RW=df[['region_txt','nwound']].groupby('region_txt').sum()
RW
# Out:
#                                nwound
# region_txt
# Australasia & Oceania           260.0
# Central America & Caribbean    8991.0
# Central Asia                   2009.0
# East Asia                      9213.0
# Eastern Europe                12045.0
# Middle East & North Africa   214308.0
# North America                 21531.0
# South America                 16704.0
# South Asia                   141360.0
# Southeast Asia                26259.0
# Sub-Saharan Africa            52857.0
# Western Europe                18332.0

# %%
RW.plot(kind='bar',figsize=(12,6))
plt.title('No. of People got Wounded in each region',fontsize=10)
plt.xlabel('Region',fontsize=10)
plt.ylabel('Wounded',fontsize=10)
plt.show()

# %% [markdown]
# *Most of the people got Wounded in Middle East & North Africa(i.e 214308)
#
# *Least of the people got Wounded in Australasia & Oceania(i.e 260)

# %% [markdown]
# # 3)Year Wise Attack Type

# %%
ATT=pd.crosstab(df.iyear,df.attacktype1_txt)
ATT.head()
# Out:
# attacktype1_txt  Armed Assault  Assassination  Bombing/Explosion  \
# iyear
# 1970                        61             22                333
# 1971                        44             70                239
# 1972                        63            265                188
# 1973                        62            164                149
# 1974                        46            158                285
#
# attacktype1_txt  Facility/Infrastructure Attack  Hijacking  \
# iyear
# 1970                                        174         11
# 1971                                         88          6
# 1972                                         19         12
# 1973                                         36          8
# 1974                                         42          3
#
# attacktype1_txt  Hostage Taking (Barricade Incident)  \
# iyear
# 1970                                               3
# 1971                                               1
# ...

# %%
ATT.plot(kind='area',figsize=(12,6),)
plt.title('Types of Attack Happened in Every Year')
plt.xlabel('Year')
plt.ylabel('Attacktype')
plt.show()

# %%
df['attacktype1_txt'].value_counts()
# Out:
# Bombing/Explosion                      88255
# Armed Assault                          42669
# Assassination                          19312
# Hostage Taking (Kidnapping)            11158
# Facility/Infrastructure Attack         10356
# Unknown                                 7276
# Unarmed Assault                         1015
# Hostage Taking (Barricade Incident)      991
# Hijacking                                659
# Name: attacktype1_txt, dtype: int64

# %%
df['attacktype1_txt'].value_counts().plot.pie(autopct='%0.f%%',startangle=90)
plt.show()

# %% [markdown]
# *Most of the Attacks were Bombing/Explosion(i.e 88255)
#
# *Least of the Attacks were Hijacking(i.e 659)

# %%
#ATTACK TYPE WISE AFFECTED
AC=df[['attacktype1_txt','Affected']].groupby('attacktype1_txt').sum()
AC
# Out:
#                                      Affected
# attacktype1_txt
# Armed Assault                        237663.0
# Assassination                         38807.0
# Bombing/Explosion                    530007.0
# Facility/Infrastructure Attack         7407.0
# Hijacking                             20719.0
# Hostage Taking (Barricade Incident)    8444.0
# Hostage Taking (Kidnapping)           30677.0
# Unarmed Assault                       14907.0
# Unknown                               47106.0

# %%
AC.plot(kind='bar',figsize=(12,6))
plt.title('People Got Affected By Different Types of Attacks',fontsize=10)
plt.xlabel('Attack Types',fontsize=11)
plt.ylabel('Affected',fontsize=11)
plt.show()

# %% [markdown]
# *Most of the people got Affected by Bombing/Explosion(i.e 530007)
#
# *Least of the people got Affected by Facility/Infrastructure Attack	(i.e 7407)

# %%
#ATTACK TYPE WISE KILLED
AK=df[['attacktype1_txt','nkill']].groupby('attacktype1_txt').sum()
AK
# Out:
#                                         nkill
# attacktype1_txt
# Armed Assault                        160297.0
# Assassination                         24920.0
# Bombing/Explosion                    157321.0
# Facility/Infrastructure Attack         3642.0
# Hijacking                              3718.0
# Hostage Taking (Barricade Incident)    4478.0
# Hostage Taking (Kidnapping)           24231.0
# Unarmed Assault                         880.0
# Unknown                               32381.0

# %%
AK.plot(kind='bar',figsize=(12,6))
plt.title('People Got Killed By Different Types of Attacks',fontsize=10)
plt.xlabel('Attack Types',fontsize=11)
plt.ylabel('Killed',fontsize=11)
plt.show()

# %% [markdown]
# *Most of the people got Killed by Armed Assault(i.e 160297)
#
# *Least of the people got Killed by Unarmed Assault (i.e 880)

# %%
#ATTACK TYPE WISE NO. OF WOUNDED
AW=df[['attacktype1_txt','nwound']].groupby('attacktype1_txt').sum()
AW
# Out:
#                                        nwound
# attacktype1_txt
# Armed Assault                         77366.0
# Assassination                         13887.0
# Bombing/Explosion                    372686.0
# Facility/Infrastructure Attack         3765.0
# Hijacking                             17001.0
# Hostage Taking (Barricade Incident)    3966.0
# Hostage Taking (Kidnapping)            6446.0
# Unarmed Assault                       14027.0
# Unknown                               14725.0

# %%
AW.plot(kind='bar',figsize=(12,6))
plt.title('People Got Wounded By Different Types of Attacks',fontsize=12)
plt.xlabel('Attack Type',fontsize=12)
plt.ylabel('Wounded',fontsize=12)
plt.show()

# %% [markdown]
# *Most of the people got Wounded by Bombing/Explosion(i.e 372686)
#
# *Least of the people got Wounded by Facility/Infrastructure Attack(i.e 3765.0)

# %% [markdown]
# # 4)Year Wise Target Type

# %%
YT=pd.crosstab(df.iyear,df.targtype1_txt)
YT.head()
# Out:
# targtype1_txt  Abortion Related  Airports & Aircraft  Business  \
# iyear
# 1970                          0                   25       136
# 1971                          0                   10       131
# 1972                          0                   22        77
# 1973                          0                   20        83
# 1974                          0                   20       179
#
# targtype1_txt  Educational Institution  Food or Water Supply  \
# iyear
# 1970                                62                     2
# 1971                                40                     0
# 1972                                 6                     0
# 1973                                 5                     0
# 1974                                 3                     0
#
# targtype1_txt  Government (Diplomatic)  Government (General)  \
# iyear
# 1970                                55                    80
# 1971                                35                    46
# ...

# %%
YTV=df['targtype1_txt'].value_counts()
YTV
# Out:
# Private Citizens & Property       43511
# Military                          27984
# Police                            24506
# Government (General)              21283
# Business                          20669
# Transportation                     6799
# Utilities                          6023
# Unknown                            5898
# Religious Figures/Institutions     4440
# Educational Institution            4322
# Government (Diplomatic)            3573
# Terrorists/Non-State Militia       3039
# Journalists & Media                2948
# Violent Political Party            1866
# Airports & Aircraft                1343
# Telecommunication                  1009
# NGO                                 970
# Tourists                            440
# Maritime                            351
# Food or Water Supply                317
# Abortion Related                    263
# Other                               137
# Name: targtype1_txt, dtype: int64

# %%
YTV.plot(kind='bar',figsize=(12,6))
plt.title('Year Wise Occurence of Targets',fontsize=11)
plt.xlabel('Target Type',fontsize=11)
plt.ylabel('Occurence of Targets',fontsize=11)
plt.show()

# %% [markdown]
# *Most of the Targets were Private Citizens and Property(i.e 43511)
#
# *Least of the Targets were other(i.e 137)

# %%
#TARGET TYPE WISE AFFECTED
TC=df[['targtype1_txt','Affected']].groupby('targtype1_txt').sum()
TC
# Out:
#                                 Affected
# targtype1_txt
# Abortion Related                    56.0
# Airports & Aircraft               7245.0
# Business                         78018.0
# Educational Institution          13972.0
# Food or Water Supply               547.0
# Government (Diplomatic)          13398.0
# Government (General)             67255.0
# Journalists & Media               3297.0
# Maritime                          2099.0
# Military                        177085.0
# NGO                               1950.0
# Other                              674.0
# Police                          118407.0
# Private Citizens & Property     319176.0
# Religious Figures/Institutions   37890.0
# Telecommunication                  679.0
# Terrorists/Non-State Militia     17311.0
# Tourists                          2048.0
# Transportation                   54595.0
# Unknown                           7888.0
# Utilities                         3227.0
# ...

# %%
TC.plot(kind='bar',figsize=(12,6))
plt.title('Target Type Wise Affected',fontsize=11)
plt.xlabel('Target Type',fontsize=11)
plt.ylabel('Affected',fontsize=11)
plt.show()

# %% [markdown]
# *Most of the people under Private Citizens & Property(i.e 319176) got Affected.
#
# *Least of the people under Abortion Related(i.e 56) got Affected.

# %%
#TARGET TYPE WISE KILLED
TK=df[['targtype1_txt','nkill']].groupby('targtype1_txt').sum()
TK
# Out:
#                                    nkill
# targtype1_txt
# Abortion Related                    10.0
# Airports & Aircraft               3767.0
# Business                         23487.0
# Educational Institution           3745.0
# Food or Water Supply               313.0
# Government (Diplomatic)           3039.0
# Government (General)             26071.0
# Journalists & Media               1501.0
# Maritime                          1191.0
# Military                        106047.0
# NGO                               1057.0
# Other                              255.0
# Police                           53704.0
# Private Citizens & Property     140504.0
# Religious Figures/Institutions   13413.0
# Telecommunication                  182.0
# Terrorists/Non-State Militia      9088.0
# Tourists                           758.0
# Transportation                   13916.0
# Unknown                           4329.0
# Utilities                         1874.0
# ...

# %%
TK.plot(kind='bar',figsize=(12,6))
plt.title('Target Type Wise Killed',fontsize=11)
plt.xlabel('Target Type',fontsize=11)
plt.ylabel('Killed',fontsize=11)
plt.show()

# %% [markdown]
# *Most of the people under Private Citizens & Property(i.e 140504) got Killed.
#
# *Least of the people under Abortion Related(i.e 10) got Killed.

# %%
#TARGET TYPE WISE WOUNDED
TW=df[['targtype1_txt','nwound']].groupby('targtype1_txt').sum()
TW
# Out:
#                                   nwound
# targtype1_txt
# Abortion Related                    46.0
# Airports & Aircraft               3478.0
# Business                         54531.0
# Educational Institution          10227.0
# Food or Water Supply               234.0
# Government (Diplomatic)          10359.0
# Government (General)             41184.0
# Journalists & Media               1796.0
# Maritime                           908.0
# Military                         71038.0
# NGO                                893.0
# Other                              419.0
# Police                           64703.0
# Private Citizens & Property     178672.0
# Religious Figures/Institutions   24477.0
# Telecommunication                  497.0
# Terrorists/Non-State Militia      8223.0
# Tourists                          1290.0
# Transportation                   40679.0
# Unknown                           3559.0
# Utilities                         1353.0
# ...

# %%
TW.plot(kind='bar',figsize=(12,6))
plt.title('Target Type Wise Wounded',fontsize=11)
plt.xlabel('Target Type',fontsize=11)
plt.ylabel('Wounded',fontsize=11)
plt.show()

# %% [markdown]
# *Most of the people under Private Citizens & Property(i.e 178672) got Wounded.
#
# *Least of the people under Abortion Related(i.e 46) got Wounded.

# %% [markdown]
# # 5)Year Wise Weapon Type Attacks

# %%
YWP=pd.crosstab(df.iyear,df.weaptype1_txt)
YWP.head()
# Out:
# weaptype1_txt  Biological  Chemical  Explosives  Fake Weapons  Firearms  \
# iyear
# 1970                    0         3         338             0        81
# 1971                    0         1         246             0       102
# 1972                    0         0         271             1       248
# 1973                    0         4         162             0       204
# 1974                    0         4         296             1       192
#
# weaptype1_txt  Incendiary  Melee  Other  Radiological  Sabotage Equipment  \
# iyear
# 1970                  176      2      0             0                   1
# 1971                   92      2      0             0                   0
# 1972                   23      5      0             0                   0
# 1973                   49      7      0             0                   0
# 1974                   43      6      0             1                   0
#
# weaptype1_txt  Unknown  \
# iyear
# 1970                49
# ...

# %%
YWP.plot(kind='area',figsize=(12,6),)
plt.title('Year Wise Weapon Type Attacks')
plt.xlabel('Year')
plt.ylabel('Weapon Type')
plt.show()

# %%
WP=df['weaptype1_txt'].value_counts()
WP
# Out:
# Explosives                                                                     92426
# Firearms                                                                       58524
# Unknown                                                                        15157
# Incendiary                                                                     11135
# Melee                                                                           3655
# Chemical                                                                         321
# Sabotage Equipment                                                               141
# Vehicle (not to include vehicle-borne explosives, i.e., car or truck bombs)      136
# Other                                                                            114
# Biological                                                                        35
# Fake Weapons                                                                      33
# ...

# %%
WP.plot(kind='bar',figsize=(12,6))
plt.title('Weapon Type Attacks',fontsize=11)
plt.xlabel('Weapon Type',fontsize=11)
plt.ylabel('No. of Times',fontsize=11)
plt.show()

# %% [markdown]
# *Explosives(92426) were most used weapon Type.
#
# *Least were Radiological(14) Weapon Type.

# %%
#WEAPON TYPE WISE AFFECTED
WPA=df[['weaptype1_txt','Affected']].groupby('weaptype1_txt').sum()
WPA
# Out:
#                                                     Affected
# weaptype1_txt
# Biological                                             814.0
# Chemical                                             14449.0
# Explosives                                          560181.0
# Fake Weapons                                             1.0
# Firearms                                            252113.0
# Incendiary                                           11006.0
# Melee                                                16070.0
# Other                                                  228.0
# Radiological                                             6.0
# Sabotage Equipment                                     369.0
# Unknown                                              60195.0
# Vehicle (not to include vehicle-borne explosive...   20305.0

# %%
WPA.plot(kind='bar',figsize=(12,6))
plt.title('Weapon Type Wise Affected',fontsize=11)
plt.xlabel('Weapon Type',fontsize=11)
plt.ylabel('Affected',fontsize=11)
plt.show()

# %% [markdown]
# *Most of the people got Affected by Explosives(560181)
#
# *Least of the people got Affected by Fake Weapons(1)

# %%
#WEAPON TYPE WISE KILLED
WPK=df[['weaptype1_txt','nkill']].groupby('weaptype1_txt').sum()
WPK
# Out:
#                                                        nkill
# weaptype1_txt
# Biological                                               9.0
# Chemical                                               624.0
# Explosives                                          174277.0
# Fake Weapons                                             1.0
# Firearms                                            174894.0
# Incendiary                                            5476.0
# Melee                                                10575.0
# Other                                                  123.0
# Radiological                                             2.0
# Sabotage Equipment                                      83.0
# Unknown                                              42620.0
# Vehicle (not to include vehicle-borne explosive...    3184.0

# %%
WPK.plot(kind='bar',figsize=(12,6))
plt.title('Weapon Type Wise Killed',fontsize=11)
plt.xlabel('Weapon Type',fontsize=11)
plt.ylabel('Killed',fontsize=11)
plt.show()

# %% [markdown]
# *Most of the people got Killed by Firearms(174894)
#
# *Least of the people got Killed by Fake Weapons(1)

# %%
#WEAPON TYPE WISE WOUNDED
WPW=df[['weaptype1_txt','nwound']].groupby('weaptype1_txt').sum()
WPW
# Out:
#                                                       nwound
# weaptype1_txt
# Biological                                             805.0
# Chemical                                             13825.0
# Explosives                                          385904.0
# Fake Weapons                                             0.0
# Firearms                                             77219.0
# Incendiary                                            5530.0
# Melee                                                 5495.0
# Other                                                  105.0
# Radiological                                             4.0
# Sabotage Equipment                                     286.0
# Unknown                                              17575.0
# Vehicle (not to include vehicle-borne explosive...   17121.0

# %%
WPW.plot(kind='bar',figsize=(12,6))
plt.title('Weapon Type Wise Wounded',fontsize=11)
plt.xlabel('Weapon Type',fontsize=11)
plt.ylabel('Wounded',fontsize=11)
plt.show()

# %% [markdown]
# *Most of the people got Wounded by Explosives(385904)
#
# *Least of the people got Wounded by Fake Weapons(1)

# %% [markdown]
# # 6)Year Wise Country Attacks

# %%
YCO=pd.crosstab(df.iyear,df.country_txt)
YCO.head()
# Out:
# country_txt  Afghanistan  Albania  Algeria  Andorra  Angola  \
# iyear
# 1970                   0        0        0        0       0
# 1971                   0        0        0        0       0
# 1972                   0        0        1        0       0
# 1973                   1        0        0        0       0
# 1974                   0        0        0        1       0
#
# country_txt  Antigua and Barbuda  Argentina  Armenia  Australia  Austria  ...  \
# iyear                                                                     ...
# 1970                           0         21        0          1        0  ...
# 1971                           0          7        0          1        0  ...
# 1972                           0         20        0          8        7  ...
# 1973                           0         60        0          0        2  ...
# 1974                           0         71        0          1        1  ...
#
# ...

# %%
YCO.plot(kind='area',figsize=(12,6),)
plt.title('Year Wise Country Attacks')
plt.xlabel('Year')
plt.ylabel('Country Attacks')
plt.show()

# %%
CO=df['country_txt'].value_counts()
CO
# Out:
# Iraq                   24636
# Pakistan               14368
# Afghanistan            12731
# India                  11960
# Colombia                8306
#                        ...
# New Hebrides               1
# Andorra                    1
# St. Lucia                  1
# North Korea                1
# Antigua and Barbuda        1
# Name: country_txt, Length: 205, dtype: int64

# %%
CO.plot(kind='bar',figsize=(40,20))
plt.title('No. of Country Attacks ',fontsize=20)
plt.xlabel('Country Attacks ',fontsize=15)
plt.ylabel('Number of Attacks',fontsize=15)
plt.show()

# %% [markdown]
# *Most of the Attacks Occurred in Iraq(24636)

# %%
#COUNTRY WISE AFFECTED
COA=df[['country_txt','Affected']].groupby('country_txt').sum()
COA
# Out:
#              Affected
# country_txt
# Afghanistan   83661.0
# Albania         168.0
# Algeria       20216.0
# Andorra           0.0
# Angola         5498.0
# ...               ...
# Yemen         18104.0
# Yugoslavia      400.0
# Zaire           535.0
# Zambia          132.0
# Zimbabwe        376.0
#
# [205 rows x 1 columns]

# %%
COA.plot(kind='bar',figsize=(40,20))
plt.title('Country Wise Affected',fontsize=20)
plt.xlabel('Countries',fontsize=20)
plt.ylabel('Affected',fontsize=20)
plt.show()

# %% [markdown]
# *Most of the People got Affected in Iraq(213279)

# %%
#COUNTRY WISE GOT KILLED
COK=df[['country_txt','nkill']].groupby('country_txt').sum()
COK
# Out:
#                nkill
# country_txt
# Afghanistan  39384.0
# Albania         42.0
# Algeria      11066.0
# Andorra          0.0
# Angola        3043.0
# ...              ...
# Yemen         8776.0
# Yugoslavia     119.0
# Zaire          324.0
# Zambia          70.0
# Zimbabwe       154.0
#
# [205 rows x 1 columns]

# %%
COK.plot(kind='bar',figsize=(40,20))
plt.title('Country Wise Killed',fontsize=20)
plt.xlabel('Countries',fontsize=20)
plt.ylabel('Killed',fontsize=20)
plt.show()

# %% [markdown]
# *Most of the People got Killed in Iraq(78589)

# %%
#COUNTRY WISE GOT WOUNDED
COW=df[['country_txt','nwound']].groupby('country_txt').sum()
COW
# Out:
#               nwound
# country_txt
# Afghanistan  44277.0
# Albania        126.0
# Algeria       9150.0
# Andorra          0.0
# Angola        2455.0
# ...              ...
# Yemen         9328.0
# Yugoslavia     281.0
# Zaire          211.0
# Zambia          62.0
# Zimbabwe       222.0
#
# [205 rows x 1 columns]

# %%
COW.plot(kind='bar',figsize=(40,20))
plt.title('Country Wise Wounded',fontsize=20)
plt.xlabel('Countries',fontsize=20)
plt.ylabel('Wounded',fontsize=20)
plt.show()

# %% [markdown]
# *Most of the People got Wounded in Iraq(134690)

# %% [markdown]
# # 7) Motive Behind Attacks

# %%
MO=df['motive'].value_counts()
MO
# Out:
# Unknown                                                                                                                                                                                                    14889
# The specific motive for the attack is unknown.                                                                                                                                                             14430
# The specific motive is unknown; however, sources noted that the attack may have been part of a larger trend of violence related to Bangladesh's nationwide hartal, which began on January 6, 2015.           297
# The specific motive for the attack is unknown..                                                                                                                                                              148
# ...

# %% [markdown]
# *Most of The Motives Where Unknown(i.e 14889)

# %%
#TOTAL NUMBER OF PEOPLE GOT AFFECTED
TotalAFF= df['Affected'].sum()
print('TOTAL NUMBER OF PEOPLE GOT AFFECTED :',TotalAFF)
# Out:
# TOTAL NUMBER OF PEOPLE GOT AFFECTED : 935737.0

# %%
#TOTAL NUMBER OF PEOPLE GOT KILLED
TotalKILL=df['nkill'].sum()
print('TOTAL NUMBER OF PEOPLE GOT KILLED :',TotalKILL)
# Out:
# TOTAL NUMBER OF PEOPLE GOT KILLED : 411868.0

# %%
#TOTAL NUMBER OF PEOPLE GOT WOUNDED
TotalWOU= df['nwound'].sum()
print('TOTAL NUMBER OF PEOPLE GOT WOUNDED :',TotalWOU)
# Out:
# TOTAL NUMBER OF PEOPLE GOT WOUNDED : 523869.0

# %% [markdown]
# # 8) Observation

# %% [markdown]
# [[1]] YEAR WISE ATTACKS
#
#   a]*Most of the Attacks Occurred in : 2014(16903)
#
#    *Least of the Attacks Occurred in :1971(471)
#
#
#   b]*Most of the People got Affected in :2014(85618)
#
#    *Least of the People got Affected in: 1971(255)
#
#
#   c]*Most of the people got Killed in :2014(44490)
#
#    *Least of the people got Killed in :1971(173)
#
#
#   d]*Most of the people got Wounded in : 2015(44043)
#
#    *Least of the people got Wounded in : 1971(82)

# %% [markdown]
# [[2]] YEAR WISE REGIONAL ATTACKS
#
#  a]*Most of the Attacks Occurred in : MIDDLE EAST & NORTH AFRICA(50474)
#
#    *Least of the Attacks Occurred in : AUSTRALASIA & OCEANIA(282)
#
#  b]*Most of the People got Affected in : MIDDLE EAST & NORTH AFRICA(351950)
#
#    *Least of the People got Affected in: AUSTRALASIA & OCEANIA(410)
#
#  c]*Most of the people got Killed in : MIDDLE EAST & NORTH AFRICA(137642)
#
#    *Least of the people got Killed in : AUSTRALASIA & OCEANIA(150)
#
#  d]*Most of the people got Wounded in : MIDDLE EAST & NORTH AFRICA(214308)
#
#    *Least of the people got Wounded in : AUSTRALASIA & OCEANIA(260)

# %% [markdown]
# [[3]] YEAR WISE ATTACK TYPE
#
#  a]*Most of the Attacks Occurred were : BOMBING/EXPLOSION(88255)
#
#    *Least of the Attacks Occurred were : HIJACKING(659)
#
#
#   b]*Most of the People got Affected in : BOMBING/EXPLOSION(530007)
#
#    *Least of the People got Affected in: FACILITY/INFRASTRUCTURE ATTACK(7407)
#
#
#   c]*Most of the people got Killed in : ARMED ASSAULT(160297)
#
#    *Least of the people got Killed in : UNARMED ASSAULT(880)
#
#
#   d]*Most of the people got Wounded in : BOMBING/EXPLOSION(372686)
#
#    *Least of the people got Wounded in :FACILITY/INFRASTRUCTURE ATTACK(37650)

# %% [markdown]
# [[4]] YEAR WISE TARGET TYPE ATTACKS
#
#   a]*Most of the Attacks Occurred in :PRIVATE CITIZENS AND PROPERTY(43511)
#
#    *Least of the Attacks Occurred in : OTHER(137)
#
#
#   b]*Most of the People got Affected in :PRIVATE CITIZENS AND PROPERTY(319176)
#
#    *Least of the People got Affected in: ABORTION RELATED(56)
#
#
#   c]*Most of the people got Killed in : PRIVATE CITIZENS AND PROPERTY(140504)
#
#    *Least of the people got Killed in : ABORTION RELATED(10)
#
#
#   d]*Most of the people got Wounded in : PRIVATE CITIZENS AND PROPERTY(178672)
#
#    *Least of the people got Wounded in : ABORTION RELATED(46)

# %% [markdown]
# [[5]] YEAR WISE WEAPON TYPE ATTACKS
#
#   a]*Most of the Attacks Occurred were : EXPLOSIVES(92426)
#
#    *Least of the Attacks Occurred were : RADIOLOGICAL(14)
#
#
#   b]*Most of the People got Affected in : EXPLOSIVES(560181)
#
#    *Least of the People got Affected in : FAKE WEAPONS(1)
#
#
#   c]*Most of the people got Killed in : FIREARMS(174894)
#
#    *Least of the people got Killed in :FAKE WEAPONS(1)
#
#
#   d]*Most of the people got Wounded in: EXPLOSIVES(385904)
#
#    *Least of the people got Wounded in :FAKE WEAPONS(1)

# %% [markdown]
# [[6]] YEAR WISE COUNTRY TYPE ATTACKS
#
#   a]*Most of the Attacks Occurred in :IRAQ(24636)
#
#   b]*Most of the People got Affected in : IRAQ(213279)
#
#   c]*Most of the people got Killed in : IRAQ(78589)
#
#   d]*Most of the people got Wounded in :IRAQ(134690)

# %% [markdown]
# [[7]] MOTIVE BEHIND ATTACKS
#
#   *Most Of The Motives behind Attacks Were Unknown.
